# %%
# Install dependencies
#%pip install anthropic python-dotenv

# %%
#load the env variable 
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
#create an api client key
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role":"user","content":text}
    messages.append(user_message)

def add_assitant_message(messages, text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,

    )
    return message.content[0].text

# %%
#Make a starting list of messages
messages = []

#Add in initial user message "Define quantum computing in one sentence"
add_user_message(messages,"Define quantum computing in one sentence")

# Pass the list of messages into 'chat' to get an answer
answer = chat(messages)

# Take the answer and add it as an assistant message into our list
add_assitant_message(messages, answer)

# Add in the user's follow-up question
add_user_message(messages, "Write another sentence")

#Call chat again with the list of messages to get a final answer
final_answer = chat(messages)

final_answer
# Out:
# 'Unlike classical computers that use bits representing either 0 or 1, quantum computers use **quantum bits (qubits)** that can exist in multiple states simultaneously, enabling them to perform vast numbers of calculations at the same time.'

# %% [markdown]
# ## Chatbot exercise

# %%
#make an initial list of messages
messages = []

#while loop to run the chatbot forever
while(True):
    #get user input
    user_input = input(">")
    print(">", user_input)

    # add user input to the list of messages 
    add_user_message(messages, user_input)

    #passing the messages to chat
    answer = chat(messages)
    
    add_assitant_message(messages, answer)

    print(">", answer)
# Out:
# > what is the color of the sun
# > ## The Color of the Sun
#
# The Sun is actually **white**. It emits light across all visible wavelengths roughly equally, which combines to appear white.
#
# ### Why it looks yellow/orange:
# - **Earth's atmosphere** scatters shorter blue wavelengths of light
# - This makes the Sun appear **yellow or orange** when viewed from Earth
# - Near the **horizon**, it can look orange or red due to even more atmospheric scattering
#
# ### Key facts:
# - In **space**, astronauts see the Sun as **white**
# - Its surface temperature (~5,500°C) produces this white light
# - It is classified as a **yellow dwarf (G-type) star**, which refers to its stellar classification, not its actual color
#
# So the short answer: **white** in reality, but **yellow** as commonly perceived from Earth's surface.
# > what are the planets name around it
# > ## Planets in Our Solar System
#
# There are **8 planets** orbiting the Sun, in order from closest to farthest:
#
# | # | Planet | Type |
# |---|--------|------|
# | 1 | **Mercury** | Rocky/Terrestrial |
# | 2 | **Venus** | Rocky/Terrestrial |
# | 3 | **Earth** | Rocky/Terrestrial |
# | 4 | **Mars** | Rocky/Terrestrial |
# | 5 | **Jupiter** | Gas Giant |
# | 6 | **Saturn** | Gas Giant |
# | 7 | **Uranus** | Ice Giant |
# | 8 | **Neptune** | Ice Giant |
#
# ### Easy Way to Remember (Mnemonic):
# **"My Very Educated Mother Just Served Us Nachos"**
# - **M**ercury, **V**enus, **E**arth, **M**ars, **J**upiter, **S**aturn, **U**ranus, **N**eptune
#
# ### Notable Facts:
# - **Jupiter** is the largest planet
# - **Mercury** is the smallest planet
# - **Saturn** is known for its beautiful **rings**
# - **Earth** is the only planet known to support **life**
# - **Pluto** was reclassified as a **dwarf planet** in 2006
# > okay what happens after sunset
# > ## What Happens After Sunset
#
# ### Immediately After Sunset:
#
# **Twilight** occurs - there are 3 stages:
#
# | Stage | Description |
# |-------|-------------|
# | **Civil Twilight** | Sun just below horizon, still bright enough to see |
# | **Nautical Twilight** | Sky getting darker, horizon barely visible |
# | **Astronomical Twilight** | Sky almost completely dark |
#
# ### Then comes **Night**:
# - 🌑 The sky becomes **fully dark**
# - ⭐ **Stars** become visible
# - 🌙 The **Moon** rises and lights up the sky
# - 🌌 The **Milky Way** may be visible in dark areas
# - 🪐 Some **planets** can be seen with naked eye
#
# ### What is actually happening:
# - The **Earth rotates** away from the Sun
# - Your side of Earth is now facing **away from the Sun**
# - Sunlight is now hitting the **other side** of Earth
#
# ### Other things that happen:
# - 🌡️ **Temperature drops**
# - 🦉 **Nocturnal animals** become active
# - 💨 **Winds** may change direction
# - 🌊 **Tides** are affected by the Moon
# - 😴 Most humans prepare for **sleep**
#
# ### Eventually:
# - **Sunrise** occurs again as Earth continues rotating
# - The cycle repeats every **24 hours**
